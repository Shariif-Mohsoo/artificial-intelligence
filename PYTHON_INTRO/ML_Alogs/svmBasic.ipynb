# %%
# going to implement svm
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x = np.array([
    [1,2],
    [3,1],
    [5,3],
    [5,1],
    [3,2],
    [5,8],
])

y= np.array([0,0,0,1,1,1])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42,stratify=y)
print(x_train)
print(x_test)
# Out:
# [[3 1]
#  [5 8]
#  [1 2]
#  [3 2]]
# [[5 1]
#  [5 3]]

# %%
scaller = StandardScaler()
x_trained_scalled = scaller.fit_transform(x_train)
x_test_scalled = scaller.transform(x_test)
print(x_trained_scalled)
print(x_test_scalled)
# Out:
# [[ 0.         -0.81150267]
#  [ 1.41421356  1.71317231]
#  [-1.41421356 -0.45083482]
#  [ 0.         -0.45083482]]
# [[ 1.41421356 -0.81150267]
#  [ 1.41421356 -0.09016696]]

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
print(x_train[:,0])
print(x_train[:,1])
plt.scatter(x_train[:,0],x_train[:,1],c=y_train,cmap="viridis")

plt.subplot(1,2,2)
plt.scatter(x_trained_scalled[:,0],x_trained_scalled[:,1],c=y_train,cmap="viridis");
plt.tight_layout()
plt.show()
# Out:
# [3 5 1 3]
# [1 8 2 2]

# %%
#train and evalute svm
linear_svm = SVC(kernel="linear",C=1.0,random_state=42);
linear_svm.fit(x_trained_scalled,y_train);
y_pred=linear_svm.predict(x_test_scalled);
accuracy=accuracy_score(y_test,y_pred);
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.5

# %%
print(classification_report(
    y_test,
    y_pred,
    zero_division=1
))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       1.00      0.00      0.00         1
#
#     accuracy                           0.50         2
#    macro avg       0.75      0.50      0.33         2
# weighted avg       0.75      0.50      0.33         2

# %%
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(
    cm,
    annot=True,
    cmap="Blues"
    xticklabel
)
# Out:
# <Axes: >
